# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from numpy import shape
import random

# %%
# Game of Life 
# die if less than two live neighbours
# survive if two or three live neighbours
# die if more than three live neighbours
# revive if three live neighbours

# %%
# evolve board according certain laws, here the law is classical game of life
def evolve(board):
    output = np.zeros(board.shape)
    for x in range (board.shape[0]):
        for y in range (board.shape[1]):
            neighbours=count_neighbours(board,x,y)
            if ((board[x,y] == 0 and neighbours == 3) or (board[x,y] == 1 and 2 <= neighbours <= 3)):
                output[x,y] = 1
    return output

# count number of alive neighbours for each cell 
def count_neighbours(board,x,y):
    neighbours = -board[x,y]
    for i in (-1, 0, 1):
        for j in (-1, 0, 1):
            xi = (x + i) % board.shape[0] # impose periodic boundary conditions
            yj = (y + j) % board.shape[1]
            neighbours += board[xi,yj]
            if neighbours > 3:
                return neighbours
    return neighbours

# define the generator that generate training data for machine to learn
# sample_size: the number of sample pair generated each time the function is called
# board_size: the size of the board
# delay: wait for this much of time after initialization to take data 
def data_generator(sample_size, board_size, delay):
    while True:
        x_train=[]
        y_train=[]
        for i in range (sample_size):
            board = np.zeros((board_size, board_size, 1)) # binary boards are randomly initialized
            boards=[]
            d = random.uniform(0,1)
            #d=0.9
            for x in range(board_size):
                for y in range(board_size):
                    if random.uniform(0,1)<d:
                        board[x,y] = 1
            for i in range (delay):
                board = evolve(board)
            x_train.append(board)
            y_train.append(evolve(board))
        x_train = np.array(x_train)
        y_train = np.array(y_train)
        yield x_train, y_train

# %%
# construct the neural network
from keras.models import Sequential, Model
from keras.layers import Lambda
import keras.layers as layers

def cyclic_padding(board):
    cyclic_board_row = tf.concat([board, board[:, :1, :, :]], axis=1)
    cyclic_board_row = tf.concat([board[:, -1:, :, :], cyclic_board_row], axis=1)
    cyclic_board = tf.concat([cyclic_board_row, cyclic_board_row[:, :, :1, :]], axis=2)   
    cyclic_board = tf.concat([cyclic_board_row[:, :, -1:, :], cyclic_board], axis=2)   
    return cyclic_board

m=8
input_state = keras.Input(shape= (10, 10, 1)) # the input size needs to match the size specified in data_generator
x = cyclic_padding(input_state)
x = layers.Conv2D(2*m, (3, 3), activation='relu')(x) # convolution layer with two filters that extract features
x = layers.Conv2D(1*m, (1, 1), activation='relu')(x) # convolution layer with one filter that mixes the features from the first layer
output_state = layers.Conv2D(1, (1, 1), activation='sigmoid')(x) # a sigmoid layer that rescale the output, making grey site closer to be binary

model = Model(input_state, output_state)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 10, 10, 1)]  0           []
#
#  tf.__operators__.getitem (Slic  (None, 1, 10, 1)    0           ['input_1[0][0]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  (None, 1, 10, 1)    0           ['input_1[0][0]']
#  icingOpLambda)
#
#  tf.concat (TFOpLambda)         (None, 11, 10, 1)    0           ['input_1[0][0]',
#                                                                   'tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.concat_1 (TFOpLambda)       (None, 12, 10, 1)    0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]',
#                                                                   'tf.concat[0][0]']
#
#  tf.__operators__.getitem_2 (Sl  (None, 12, 1, 1)    0           ['tf.concat_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_3 (Sl  (None, 12, 1, 1)    0           ['tf.concat_1[0][0]']
#  icingOpLambda)
#
#  tf.concat_2 (TFOpLambda)       (None, 12, 11, 1)    0           ['tf.concat_1[0][0]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]']
#
#  tf.concat_3 (TFOpLambda)       (None, 12, 12, 1)    0           ['tf.__operators__.getitem_3[0][0
#                                                                  ]',
#                                                                   'tf.concat_2[0][0]']
#
#  conv2d (Conv2D)                (None, 10, 10, 16)   160         ['tf.concat_3[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 10, 10, 8)    136         ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 10, 10, 1)    9           ['conv2d_1[0][0]']
#
# ==================================================================================================
# Total params: 305
# Trainable params: 305
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# train the neural network 

keras.backend.clear_session() # refresh model each time

#model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.3), loss='mse')
model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.1), loss='binary_crossentropy')
history = model.fit(data_generator(1, 10, 5), epochs=100, steps_per_epoch=20)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 51ms/step - loss: 0.5235
# Epoch 2/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.3158
# Epoch 3/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.3956
# Epoch 4/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.2738
# Epoch 5/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.2453
# Epoch 6/100
# 20/20 [==============================] - 1s 60ms/step - loss: 0.2951
# Epoch 7/100
# 20/20 [==============================] - 1s 45ms/step - loss: 0.2323
# Epoch 8/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.2629
# Epoch 9/100
# 20/20 [==============================] - 1s 52ms/step - loss: 0.1021
# Epoch 10/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.2658
# Epoch 11/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.1657
# Epoch 12/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.2095
# Epoch 13/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1719
# Epoch 14/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.1494
# Epoch 15/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1677
# Epoch 16/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1797
# Epoch 17/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.1211
# Epoch 18/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1830
# Epoch 19/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.1307
# Epoch 20/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.1811
# Epoch 21/100
# 20/20 [==============================] - 1s 41ms/step - loss: 0.1004
# Epoch 22/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.1309
# Epoch 23/100
# 20/20 [==============================] - 1s 55ms/step - loss: 0.0932
# Epoch 24/100
# 20/20 [==============================] - 1s 54ms/step - loss: 0.1264
# Epoch 25/100
# 20/20 [==============================] - 1s 57ms/step - loss: 0.1170
# Epoch 26/100
# 20/20 [==============================] - 1s 41ms/step - loss: 0.2152
# Epoch 27/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1656
# Epoch 28/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.2183
# Epoch 29/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0928
# Epoch 30/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1433
# Epoch 31/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1663
# Epoch 32/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0990
# Epoch 33/100
# 20/20 [==============================] - 1s 42ms/step - loss: 0.1731
# Epoch 34/100
# 20/20 [==============================] - 1s 41ms/step - loss: 0.1036
# Epoch 35/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.1366
# Epoch 36/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.1076
# Epoch 37/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.1638
# Epoch 38/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.1171
# Epoch 39/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1162
# Epoch 40/100
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0855
# Epoch 41/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.1255
# Epoch 42/100
# 20/20 [==============================] - 1s 53ms/step - loss: 0.0805
# Epoch 43/100
# 20/20 [==============================] - 1s 57ms/step - loss: 0.0896
# Epoch 44/100
# 20/20 [==============================] - 1s 64ms/step - loss: 0.1376
# Epoch 45/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.1006
# Epoch 46/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0940
# Epoch 47/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0560
# Epoch 48/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0911
# Epoch 49/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.1190
# Epoch 50/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0834
# Epoch 51/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0969
# Epoch 52/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0484
# Epoch 53/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0838
# Epoch 54/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0701
# Epoch 55/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0713
# Epoch 56/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0433
# Epoch 57/100
# 20/20 [==============================] - 1s 43ms/step - loss: 0.0756
# Epoch 58/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0440
# Epoch 59/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0395
# Epoch 60/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0642
# Epoch 61/100
# 20/20 [==============================] - 1s 49ms/step - loss: 0.0527
# Epoch 62/100
# 20/20 [==============================] - 1s 56ms/step - loss: 0.0499
# Epoch 63/100
# 20/20 [==============================] - 1s 59ms/step - loss: 0.0639
# Epoch 64/100
# 20/20 [==============================] - 1s 49ms/step - loss: 0.0555
# Epoch 65/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0319
# Epoch 66/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0651
# Epoch 67/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0423
# Epoch 68/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0466
# Epoch 69/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0288
# Epoch 70/100
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0437
# Epoch 71/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0423
# Epoch 72/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0332
# Epoch 73/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0333
# Epoch 74/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0315
# Epoch 75/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0319
# Epoch 76/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0312
# Epoch 77/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0204
# Epoch 78/100
# 20/20 [==============================] - 1s 41ms/step - loss: 0.0270
# Epoch 79/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0158
# Epoch 80/100
# 20/20 [==============================] - 1s 46ms/step - loss: 0.0193
# Epoch 81/100
# 20/20 [==============================] - 1s 58ms/step - loss: 0.0239
# Epoch 82/100
# 20/20 [==============================] - 1s 62ms/step - loss: 0.0232
# Epoch 83/100
# 20/20 [==============================] - 1s 44ms/step - loss: 0.0155
# Epoch 84/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0195
# Epoch 85/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0229
# Epoch 86/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0171
# Epoch 87/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0305
# Epoch 88/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0177
# Epoch 89/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0158
# Epoch 90/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0162
# Epoch 91/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0204
# Epoch 92/100
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0178
# Epoch 93/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0161
# Epoch 94/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0156
# Epoch 95/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0140
# Epoch 96/100
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0068
# Epoch 97/100
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0122
# Epoch 98/100
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0108
# Epoch 99/100
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0057
# Epoch 100/100
# 20/20 [==============================] - 1s 57ms/step - loss: 0.0099

# %%
# generate test samples and verify the learning outcome

def board_generator(sample_size, board_size, delay):
    x_test=[]
    y_test=[]
    for i in range (sample_size):
        board = np.zeros((board_size, board_size, 1))
        boards=[]
        d = random.uniform(0.1,0.7)
        #d=0.9
        for x in range(board_size):
            for y in range(board_size):
                if random.uniform(0,1)<d:
                    board[x,y,0] = 1
        for i in range (delay):
            board = evolve(board)
        x_test.append(board)
        y_test.append(evolve(board))
    x_test = np.array(x_test)
    y_test = np.array(y_test)
    y_pred = model.predict(x_test)
    return x_test, y_test, y_pred

data = board_generator(10,10,5)

print(shape(data))
for i in range (len(data)):
    fig,ax=plt.subplots(1,shape(data[1])[0],figsize=(50, 50))
    for j in range (shape(data[1])[0]):
        ax[j].imshow(data[i][j],cmap=plt.cm.Greys)
        
# the first row is the test boards at time t 
# the second row is the corresponding test boards at time t+1
# the third row is the predicted boards at t+1 given by machine based on the test boards at time t
# Out:
# 1/1 [==============================] - 0s 18ms/step
# (3, 10, 10, 10, 1)
